#        -2.05224961,  0.65445566,  0.68781812, -0.61118239,  0.81422183,
#         1.96697794, -1.47084128,  1.29973828, -1.06785506,  0.36460124,
#         1.25906399, -0.02390113,  0.01443844,  0.5762097 ,  0.40383333,
#        -2.45639746,  0.2252377 ,  0.46477755, -0.09367714, -1.25877895,
#        -0.47018088, -0.314091  ,  2.94012458, -0.83734086,  0.33723913])

# %%
plt.figure(figsize= (5, 5))

plt.scatter(x, y)

# %%
plt.figure(figsize= (5, 5))

plt.scatter(x, y, s= 100)

# %%
plt.figure(figsize= (5, 5))

plt.scatter(x, y, s= 100)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (5, 5))

plt.scatter(x, y, s= 50)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (5, 5))

plt.scatter(x, y, s= 300)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (5, 5))

size= np.random.randint(10, 100, size= 100)

plt.scatter(x, y, s= size)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
size= np.random.randint(10, 100, size= 100)
size
# Out:
# array([94, 33, 70, 48, 50, 20, 82, 55, 92, 70, 59, 83, 25, 45, 60, 33, 55,
#        34, 63, 64, 77, 21, 38, 24, 91, 98, 54, 37, 71, 79, 53, 68, 27, 75,
#        70, 31, 14, 93, 82, 25, 83, 51, 62, 73, 24, 34, 36, 92, 60, 34, 46,
#        67, 92, 99, 65, 26, 48, 96, 82, 53, 95, 99, 21, 16, 95, 93, 85, 51,
#        56, 64, 46, 81, 55, 10, 76, 32, 91, 26, 55, 54, 45, 43, 67, 33, 75,
#        82, 44, 12, 17, 59, 44, 13, 14, 36, 95, 77, 77, 28, 86, 62])

# %%
size= np.random.randint(10, 100, size= 200)
size
# Out:
# array([76, 55, 49, 54, 87, 94, 20, 66, 15, 37, 31, 49, 87, 64, 30, 89, 88,
#        47, 91, 58, 98, 55, 55, 33, 29, 99, 12, 98, 33, 82, 69, 94, 47, 13,
#        22, 35, 24, 63, 81, 83, 92, 15, 10, 85, 36, 64, 33, 22, 84, 36, 37,
#        23, 44, 56, 33, 30, 31, 11, 22, 78, 93, 48, 53, 42, 49, 18, 72, 52,
#        14, 27, 12, 62, 67, 17, 74, 63, 36, 32, 20, 52, 44, 87, 25, 62, 30,
#        23, 65, 98, 47, 54, 72, 74, 93, 69, 82, 37, 78, 49, 62, 96, 21, 47,
#        87, 91, 24, 26, 91, 50, 99, 50, 72, 24, 33, 75, 30, 62, 42, 55, 24,
#        66, 78, 33, 19, 25, 71, 91, 12, 66, 97, 53, 38, 10, 30, 47, 95, 32,
#        31, 32, 88, 34, 77, 81, 90, 10, 70, 64, 21, 52, 48, 26, 92, 33, 89,
#        23, 52, 65, 43, 69, 45, 83, 51, 50, 41, 52, 49, 58, 73, 71, 15, 93,
#        26, 77, 34, 51, 67, 80, 57, 86, 36, 49, 36, 58, 51, 95, 57, 60, 56,
#        40, 42, 93, 19, 81, 83, 19, 69, 56, 47, 66, 78, 72])

# %%
size= np.random.randint(10, 300, size= 100)
size
# Out:
# array([ 75,  30, 197, 279, 140, 261, 176, 273, 290,  47, 102, 219, 211,
#        109, 226,  59, 119, 281,  44, 106,  55,  40,  99, 279, 294,  18,
#        269, 176, 142,  88, 157,  69, 290, 119, 225,  11,  19, 266, 274,
#         95, 100,  20, 291,  20, 275, 271, 140, 157, 174,  26, 187, 269,
#         89,  62,  57, 174, 174, 159, 299,  49, 297, 216, 214, 248,  82,
#        209,  29, 137, 107, 131,  91, 295, 236,  14,  18, 238,  26, 202,
#        116, 141,  28,  19, 286, 127, 275, 264, 119, 183, 131, 280,  71,
#        188, 212,  90,  60, 203,  14, 217,  96, 295])

# %%
plt.figure(figsize= (5, 5))

condition = x > 0
size= np.where(condition, 50, 10)

plt.scatter(x, y, s= size)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (5, 5))

condition = x > 0
size= np.where(condition, 120, 20)

plt.scatter(x, y, s= size)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
size
# Out:
# array([120, 120, 120, 120, 120,  20, 120, 120,  20,  20, 120, 120, 120,
#         20, 120, 120, 120,  20, 120,  20, 120, 120, 120, 120,  20,  20,
#         20, 120,  20,  20,  20, 120, 120, 120,  20, 120, 120, 120,  20,
#        120,  20, 120, 120, 120, 120, 120,  20, 120,  20, 120, 120,  20,
#         20,  20,  20,  20, 120, 120, 120, 120,  20, 120, 120,  20, 120,
#        120, 120, 120,  20,  20,  20, 120,  20,  20,  20, 120,  20,  20,
#         20,  20,  20,  20,  20,  20, 120,  20, 120, 120,  20,  20, 120,
#         20,  20,  20,  20, 120,  20, 120, 120,  20])

# %%
plt.figure(figsize= (5, 5))

condition = x > 0
size= np.where(condition, 120, 20)

plt.scatter(x, y, s= size)

plt.title("Scatter Plot with Custom Dot Size")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')
