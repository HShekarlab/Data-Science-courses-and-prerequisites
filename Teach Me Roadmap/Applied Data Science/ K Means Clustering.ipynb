# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data_for_kmean.csv")

# %%
df
# Out:
#      Feature 1  Feature 2
# 0    -6.428841  10.141117
# 1     5.868679   5.201104
# 2    -0.376109   3.264279
# 3     2.166792   9.563005
# 4     5.095086   7.207527
# ..         ...        ...
# 195   0.671402   4.975115
# 196   6.560002   8.351321
# 197   5.134971   9.125419
# 198  -9.261985  -4.336104
# 199   2.174744   1.131476
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Feature 1  200 non-null    float64
#  1   Feature 2  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.describe()
# Out:
#         Feature 1   Feature 2
# count  200.000000  200.000000
# mean    -2.392565    2.518865
# std      5.227262    6.013580
# min    -14.357106  -10.376770
# 25%     -7.023589   -2.166336
# 50%     -1.580804    4.231853
# 75%      1.750998    7.464115
# max      8.718557   11.392017

# %%
sns.scatterplot(x= df["Feature 1"], y= df["Feature 2"])
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters= 4)

# %%
kmeans.fit(df)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([2, 3, 0, 3, 3, 1, 3, 0, 3, 0, 2, 0, 3, 3, 2, 0, 3, 0, 1, 2, 1, 0,
#        0, 1, 2, 1, 1, 0, 3, 3, 2, 1, 3, 0, 0, 2, 1, 1, 1, 0, 1, 2, 2, 2,
#        0, 3, 2, 0, 1, 0, 0, 2, 3, 0, 1, 2, 0, 0, 2, 3, 1, 3, 1, 2, 3, 0,
#        1, 3, 3, 1, 3, 0, 1, 0, 1, 3, 3, 0, 2, 0, 0, 1, 3, 1, 0, 0, 0, 2,
#        0, 1, 1, 1, 1, 0, 0, 1, 3, 2, 1, 3, 0, 1, 0, 0, 3, 0, 1, 3, 1, 1,
#        3, 2, 2, 3, 1, 3, 2, 2, 3, 2, 0, 2, 0, 2, 0, 3, 2, 0, 1, 2, 2, 2,
#        0, 1, 1, 2, 3, 2, 3, 0, 1, 3, 1, 2, 2, 3, 0, 1, 2, 2, 2, 2, 0, 3,
#        0, 2, 3, 3, 3, 0, 3, 0, 0, 2, 1, 2, 0, 3, 2, 0, 3, 0, 2, 3, 0, 2,
#        3, 3, 1, 3, 2, 1, 1, 2, 1, 1, 1, 1, 1, 0, 1, 3, 3, 2, 1, 0, 3, 3,
#        1, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.0123077 ,  2.13407664],
#        [-9.46941837, -6.56081545],
#        [-4.13591321,  7.95389851],
#        [ 3.71749226,  7.01388735]])

# %%
df_k = df

# %%
df_k["Lable : K = 4"] = kmeans.labels_

# %%
df_k
# Out:
#      Feature 1  Feature 2  Lable : K = 4
# 0    -6.428841  10.141117              2
# 1     5.868679   5.201104              3
# 2    -0.376109   3.264279              0
# 3     2.166792   9.563005              3
# 4     5.095086   7.207527              3
# ..         ...        ...            ...
# 195   0.671402   4.975115              0
# 196   6.560002   8.351321              3
# 197   5.134971   9.125419              3
# 198  -9.261985  -4.336104              1
# 199   2.174744   1.131476              0
#
# [200 rows x 3 columns]

# %%
sns.scatterplot(data= df_k, x= "Feature 1", y= "Feature 2", hue= "Lable : K = 4", palette= "viridis")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
kmeans_1 = KMeans(n_clusters= 2)

# %%
kmeans_1.fit(df)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
df_k["Lable : K = 2"] = kmeans_1.labels_

# %%
df_k
# Out:
#      Feature 1  Feature 2  Lable : K = 4  Lable : K = 2
# 0    -6.428841  10.141117              2              1
# 1     5.868679   5.201104              3              1
# 2    -0.376109   3.264279              0              1
# 3     2.166792   9.563005              3              1
# 4     5.095086   7.207527              3              1
# ..         ...        ...            ...            ...
# 195   0.671402   4.975115              0              1
# 196   6.560002   8.351321              3              1
# 197   5.134971   9.125419              3              1
# 198  -9.261985  -4.336104              1              0
# 199   2.174744   1.131476              0              1
#
# [200 rows x 4 columns]

# %%
sns.scatterplot(data= df_k, x="Feature 1", y="Feature 2", hue="Lable : K = 2", palette= "cubehelix")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize= (10, 5))
ax1.set_title("K Mean(K = 4)")
ax1.scatter(x= df_k["Feature 1"], y= df_k["Feature 2"], c= df_k["Lable : K = 4"], cmap= "Dark2")
ax2.set_title("K Mean(K = 2)")
ax2.scatter(x= df_k["Feature 1"], y= df_k["Feature 2"], c= df_k["Lable : K = 2"], cmap= "Dark2")

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples= 200, 
                  n_features= 2, 
                  centers= 4, 
                  cluster_std= 1.8,
                  random_state= 101)

# %%
data
# Out:
# (array([[-6.42884095e+00,  1.01411174e+01],
#         [ 5.86867888e+00,  5.20110356e+00],
#         [-3.76109375e-01,  3.26427943e+00],
#         [ 2.16679181e+00,  9.56300522e+00],
#         [ 5.09508570e+00,  7.20752718e+00],
#         [-1.08788882e+01, -6.11318040e+00],
#         [ 2.03405554e+00,  9.76664755e+00],
#         [-1.71798771e+00,  1.41401140e+00],
#         [ 1.16911341e+00,  8.24556988e+00],
#         [-1.35185444e+00,  3.13245345e+00],
#         [-6.18548214e+00,  9.67406555e+00],
#         [-1.19856602e+00,  2.50408937e+00],
#         [ 2.90296863e+00,  7.91251003e+00],
#         [ 2.39250023e+00,  5.38173971e+00],
#         [-5.27545147e+00,  9.63836659e+00],
#         [-5.66814687e-01,  5.60262755e-02],
#         [ 5.97336628e+00,  5.87172022e+00],
#         [-2.31355268e+00,  5.23980092e-01],
#         [-1.01344756e+01, -3.43130837e+00],
#         [-4.54082629e+00,  1.13920174e+01],
#         [-1.04155833e+01, -5.67545836e+00],
# ...

# %%
type(data)
# Out:
# tuple

# %%
len(data)
# Out:
# 2

# %%
data[0]
# Out:
# array([[-6.42884095e+00,  1.01411174e+01],
#        [ 5.86867888e+00,  5.20110356e+00],
#        [-3.76109375e-01,  3.26427943e+00],
#        [ 2.16679181e+00,  9.56300522e+00],
#        [ 5.09508570e+00,  7.20752718e+00],
#        [-1.08788882e+01, -6.11318040e+00],
#        [ 2.03405554e+00,  9.76664755e+00],
#        [-1.71798771e+00,  1.41401140e+00],
#        [ 1.16911341e+00,  8.24556988e+00],
#        [-1.35185444e+00,  3.13245345e+00],
#        [-6.18548214e+00,  9.67406555e+00],
#        [-1.19856602e+00,  2.50408937e+00],
#        [ 2.90296863e+00,  7.91251003e+00],
#        [ 2.39250023e+00,  5.38173971e+00],
#        [-5.27545147e+00,  9.63836659e+00],
#        [-5.66814687e-01,  5.60262755e-02],
#        [ 5.97336628e+00,  5.87172022e+00],
#        [-2.31355268e+00,  5.23980092e-01],
#        [-1.01344756e+01, -3.43130837e+00],
#        [-4.54082629e+00,  1.13920174e+01],
#        [-1.04155833e+01, -5.67545836e+00],
#        [ 6.64796693e-01,  9.42304718e-02],
# ...

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
len(data[0])
# Out:
# 200

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
data[0][1]
# Out:
# array([5.86867888, 5.20110356])

# %%
data[0][:, 0]
# Out:
# array([-6.42884095e+00,  5.86867888e+00, -3.76109375e-01,  2.16679181e+00,
#         5.09508570e+00, -1.08788882e+01,  2.03405554e+00, -1.71798771e+00,
#         1.16911341e+00, -1.35185444e+00, -6.18548214e+00, -1.19856602e+00,
#         2.90296863e+00,  2.39250023e+00, -5.27545147e+00, -5.66814687e-01,
#         5.97336628e+00, -2.31355268e+00, -1.01344756e+01, -4.54082629e+00,
#        -1.04155833e+01,  6.64796693e-01,  2.11460477e+00, -1.11790221e+01,
#        -6.63698251e+00, -7.67422005e+00, -7.98668260e+00,  1.27983684e+00,
#         3.54480244e+00,  4.03940181e+00, -2.88118898e+00, -9.11009911e+00,
#         5.26001172e+00,  2.05859724e+00, -1.71289834e+00, -5.40562319e+00,
#        -1.11995123e+01, -1.13753641e+01, -1.17821836e+01,  1.74815503e+00,
#        -9.00392334e+00, -2.86564584e+00, -1.42742293e+00, -3.10933432e+00,
#         2.71130095e-01,  8.21556561e-01, -4.11495481e+00,  1.55414928e+00,
# ...

# %%
data[0][:, 1]
# Out:
# array([ 10.14111739,   5.20110356,   3.26427943,   9.56300522,
#          7.20752718,  -6.1131804 ,   9.76664755,   1.4140114 ,
#          8.24556988,   3.13245345,   9.67406555,   2.50408937,
#          7.91251003,   5.38173971,   9.63836659,   0.05602628,
#          5.87172022,   0.52398009,  -3.43130837,  11.39201739,
#         -5.67545836,   0.09423047,   3.55938488,  -9.30976605,
#          6.39426436,  -7.26839654,  -9.57113308,   0.35315078,
#          7.93535678,   4.88870433,   9.12919391,  -7.6978166 ,
#          4.74007434,  -2.44083039,   2.51221197,   7.47228315,
#         -2.55276744,  -4.94525091,  -9.50883007,   2.05595679,
#         -6.20816203,   7.52934153,   8.33519078,  10.16414643,
#          2.58303824,   6.76966806,   8.02621345,   3.27657687,
#         -8.0067372 ,   4.90466211,  -0.5949262 ,   7.19997027,
#          4.0169624 ,   0.67345201,  -5.61883075,   5.98523639,
#          4.462053  ,   1.81203497,   5.29262653,   6.73039191,
# ...

# %%
df_dict= {"Feature 1": data[0][:,0],
          "Feature 2": data[0][:,1]}

# %%
final_df= pd.DataFrame.from_dict(df_dict)

# %%
final_df.to_csv("Data_for_kmean.csv", index= False)

# %%
sns.scatterplot(x= final_df["Feature 1"], y= final_df["Feature 2"])
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
k = 1

# %%
kmeans = KMeans(n_clusters= k)

# %%
kmeans.fit(df)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=1)

# %%
kmeans.inertia_
# Out:
# 12929.173683268436

# %%
sse = {}

# %%
for k in range(1, 10):
    kmeans = KMeans(n_clusters= k)
    kmeans.fit(df)
    sse[k] = kmeans.inertia_
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
sse
# Out:
# {1: 12929.173683268436,
#  2: 4042.736243274673,
#  3: 2525.13496176229,
#  4: 1318.4035725547487,
#  5: 1162.3522949896858,
#  6: 1021.954018726846,
#  7: 870.2577328176662,
#  8: 778.1160783627738,
#  9: 695.2393622312851}

# %%
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
# Out:
# Text(0, 0.5, 'SSE')
