# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
values = [87, 53, 66, 61, 68, 62, 110, 104, 61, 111, 123, 117, 119, 116, 104, 92, 111, 90, 103, 81, 80, 101, 51, 79, 107, 110, 129, 145, 139, 110]

# %%
plt.figure(figsize= (5, 5))

plt.hist(values)
# Out:
# (array([2., 5., 1., 3., 2., 5., 6., 3., 1., 2.]),
#  array([ 51. ,  60.4,  69.8,  79.2,  88.6,  98. , 107.4, 116.8, 126.2,
#         135.6, 145. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, bins= 4)
# Out:
# (array([ 7.,  6., 13.,  4.]),
#  array([ 51. ,  74.5,  98. , 121.5, 145. ]),
#  <BarContainer object of 4 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, bins= 4, edgecolor= "black")
# Out:
# (array([ 7.,  6., 13.,  4.]),
#  array([ 51. ,  74.5,  98. , 121.5, 145. ]),
#  <BarContainer object of 4 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, bins= 4, edgecolor= "black", color= "g")
# Out:
# (array([ 7.,  6., 13.,  4.]),
#  array([ 51. ,  74.5,  98. , 121.5, 145. ]),
#  <BarContainer object of 4 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, bins= 10, edgecolor= "black", color= "y")
# Out:
# (array([2., 5., 1., 3., 2., 5., 6., 3., 1., 2.]),
#  array([ 51. ,  60.4,  69.8,  79.2,  88.6,  98. , 107.4, 116.8, 126.2,
#         135.6, 145. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, bins= 15, edgecolor= "black", color= "c")
# Out:
# (array([2., 3., 2., 0., 3., 1., 2., 1., 4., 5., 3., 1., 1., 0., 2.]),
#  array([ 51.        ,  57.26666667,  63.53333333,  69.8       ,
#          76.06666667,  82.33333333,  88.6       ,  94.86666667,
#         101.13333333, 107.4       , 113.66666667, 119.93333333,
#         126.2       , 132.46666667, 138.73333333, 145.        ]),
#  <BarContainer object of 15 artists>)

# %%
plt.figure(figsize= (5, 5))

plt.hist(values, edgecolor= "black", color= "m")
# Out:
# (array([2., 5., 1., 3., 2., 5., 6., 3., 1., 2.]),
#  array([ 51. ,  60.4,  69.8,  79.2,  88.6,  98. , 107.4, 116.8, 126.2,
#         135.6, 145. ]),
#  <BarContainer object of 10 artists>)
