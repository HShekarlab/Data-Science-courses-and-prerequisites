# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.title("Sin Wave")
# Out:
# Text(0.5, 1.0, 'Sin Wave')

# %%
plt.savefig("039-sin_fig.png")
