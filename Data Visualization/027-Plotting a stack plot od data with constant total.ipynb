# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.array([[10, 20, 30, 40],
                 [20, 30, 10, 40],
                 [30, 10, 20, 40]])

totals = np.sum(data, axis= 0)
percentages = data / totals[np.newaxis, :] * 100

# %%
data
# Out:
# array([[10, 20, 30, 40],
#        [20, 30, 10, 40],
#        [30, 10, 20, 40]])

# %%
totals
# Out:
# array([ 60,  60,  60, 120])

# %%
percentages
# Out:
# array([[16.66666667, 33.33333333, 50.        , 33.33333333],
#        [33.33333333, 50.        , 16.66666667, 33.33333333],
#        [50.        , 16.66666667, 33.33333333, 33.33333333]])

# %%
plt.figure(figsize= (5, 5))

fig, ax = plt.subplots()

ax.stackplot(range(4), percentages, labels= ["Category 1", "Category 2", "Category 3"])

ax.legend(loc= "upper left")
ax.set_title("100% Stacked Plot")
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")
# Out:
# Text(0, 0.5, 'Y axis label')
