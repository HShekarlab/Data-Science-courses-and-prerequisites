# %%
import numpy as np
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [189, 185, 195, 149, 189, 147, 154, 174, 169, 195, 159, 192, 155, 191, 153, 157, 140, 144, 172, 157, 181, 182, 166, 167, 140, 130, 150,
        190, 171, 189, 142, 153, 159, 161, 169, 165, 133, 188]

# %%
plt.figure(figsize= (5, 5))

plt.hist(data, bins= 50, color= "c", edgecolor= "k")
# Out:
# (array([1., 0., 1., 0., 0., 0., 0., 2., 0., 1., 1., 0., 0., 1., 1., 1., 0.,
#         2., 1., 1., 2., 0., 2., 1., 0., 0., 1., 1., 1., 0., 2., 1., 1., 1.,
#         0., 0., 0., 0., 0., 1., 1., 0., 1., 0., 1., 3., 2., 1., 0., 2.]),
#  array([130. , 131.3, 132.6, 133.9, 135.2, 136.5, 137.8, 139.1, 140.4,
#         141.7, 143. , 144.3, 145.6, 146.9, 148.2, 149.5, 150.8, 152.1,
#         153.4, 154.7, 156. , 157.3, 158.6, 159.9, 161.2, 162.5, 163.8,
#         165.1, 166.4, 167.7, 169. , 170.3, 171.6, 172.9, 174.2, 175.5,
#         176.8, 178.1, 179.4, 180.7, 182. , 183.3, 184.6, 185.9, 187.2,
#         188.5, 189.8, 191.1, 192.4, 193.7, 195. ]),
#  <BarContainer object of 50 artists>)

# %%
m = statistics.mean(data)
sd = statistics.stdev(data)

plt.figure(figsize= (5, 5))

plt.hist(data, bins= 50, color= "c", edgecolor= "k")

plt.axvline(m, color= "r", linestyle= "--")

# %%
m = statistics.mean(data)
sd = statistics.stdev(data)

plt.figure(figsize= (5, 5))

plt.hist(data, bins= 50, color= "c", edgecolor= "k")

plt.axvline(m, color= "r", linestyle= "--")

plt.axvline(m + sd, color= "g", linestyle= "--")

# %%
m = statistics.mean(data)
sd = statistics.stdev(data)

plt.figure(figsize= (5, 5))

plt.hist(data, bins= 50, color= "c", edgecolor= "k")

plt.axvline(m, color= "r", linestyle= "--")
plt.axvline(m + sd, color= "g", linestyle= "--")
plt.axvline(m - sd, color= "g", linestyle= "--")
