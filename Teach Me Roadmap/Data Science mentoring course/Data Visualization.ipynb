# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Tips = sns.load_dataset("tips")

# %%
Tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
Tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
Tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
Tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(data= Tips, x= "sex", color= "g", width= 0.6)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "time", color= "y")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "sex", hue= "day")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "sex", hue= "time")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "sex", hue= "smoker")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "smoker", hue= "time")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "day", hue= "time")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data= Tips, x= "time", hue= "day")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
x = Tips["total_bill"]

# %%
sns.displot(x)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x, kde= True)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x= Tips["total_bill"], y= Tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data= Tips, x= "day", y= "total_bill", palette= "rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data= Tips, x= "day", y= "total_bill", palette= "coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data= Tips, x= "time", y= "total_bill", palette= "rainbow")
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(Tips)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(Tips, hue= "sex", palette= "coolwarm")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(Tips, hue= "day", palette= "coolwarm")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(Tips, hue= "time", palette= "coolwarm")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "scatter")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "hist")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "hex")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "kde")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "reg")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "tip", kind= "resid")

# %%
sns.jointplot(data= Tips, x= "total_bill", y= "size", kind= "scatter")

# %%
sns.jointplot(data= Tips, x= "tip", y= "size", kind= "scatter")

# %%
plt.subplot(1, 2, 1)
sns.countplot(data= Tips, x= "sex", color= "g")

plt.subplot(1, 2, 2)
sns.countplot(data= Tips, x= "day", color= "m")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.subplot(2, 2, 1)
sns.countplot(data= Tips, x= "sex", color= "b")

plt.subplot(2, 2, 2)
sns.countplot(data= Tips, x= "day", color= "g")

plt.subplot(2, 2, 3)
sns.countplot(data= Tips, x= "time", color= "m")

plt.subplot(2, 2, 4)
sns.countplot(data= Tips, x= "smoker", color= "r")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>
