# %% [markdown]
# ***This will enable the use of Cufflinks with Plotly in offline mode***

# %%
import pandas as pd
import plotly.express as px
import cufflinks as cf
cf.go_offline()

# import plotly.offline as pyo
# import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ***Line Plot***

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")
df
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
# ...

# %%
fig = px.line(df, x= "Date", y= "AAPL.High", title= "AAPL High Price")
fig.show()

# %% [markdown]
# ***Scatter Plot***

# %%
fig = px.scatter(df, x= "Date", y= "AAPL.High", title= "AAPL High Price")
fig.show()

# %% [markdown]
# ***Bar Plot***

# %%
fig = px.bar(df, x= "Date", y= "AAPL.High", title= "AAPL High Price")
fig.show()

# %%
fig = px.bar(df, x= "Date", y= "AAPL.High", title= "AAPL High Price", template= "plotly_dark")
fig.show()

# %% [markdown]
# ***Box Plot & Area Plot***

# %%
fig = px.box(df, x= "Date", y= "AAPL.High", title= "AAPL High Price")
fig.show()

# %%
fig = px.box(df, x= "Date", y= "AAPL.High", title= "AAPL High Price", template= "plotly_dark")
fig.show()

# %%
fig = px.area(df, x= "Date", y= "AAPL.High", title= "AAPL High Price")
fig.show()

# %%
fig = px.area(df, x= "Date", y= "AAPL.High", title= "AAPL High Price", template= "plotly_dark")
fig.show()

# %%
data = pd.DataFrame({"x": [1, 2, 3, 4, 5],
                     "y_1": [2, 4, 1, 5, 3],
                     "y_2": [1, 3, 2, 4, 2]})

fig = px.area(data, x= "x", y= ["y_1", "y_2"], title= "Area Plot")
fig.show()

# %%
data = pd.DataFrame({"x": [1, 2, 3, 4, 5],
                     "y_1": [2, 4, 1, 5, 3],
                     "y_2": [1, 3, 2, 4, 2]})

fig = px.area(data, x= "x", y= ["y_1", "y_2"], title= "Area Plot", template= "plotly_dark")
fig.show()
