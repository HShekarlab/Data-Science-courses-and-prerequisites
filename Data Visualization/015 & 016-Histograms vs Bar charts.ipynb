# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ***Bar Chart***

# %%
languages = ["C", "C++", "Java", "Python", "PHP"]
students = [11, 17, 30, 43, 20]

plt.figure(figsize= (5, 5))

plt.bar(languages, students)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ***Histogram***

# %%
height = [189, 185, 195, 149, 189, 147, 154, 174, 169, 195, 159, 192, 155, 191, 153, 157, 140, 144, 172, 157, 181, 182, 166, 167]

plt.figure(figsize= (5, 5))

plt.hist(height)
# Out:
# (array([2., 2., 3., 3., 2., 2., 1., 2., 3., 4.]),
#  array([140. , 145.5, 151. , 156.5, 162. , 167.5, 173. , 178.5, 184. ,
#         189.5, 195. ]),
#  <BarContainer object of 10 artists>)
