# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axes = plt.subplots()

print(fig)
# Out:
# Figure(640x480)

# %%
fig, axes = plt.subplots()

print(axes)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 3, figsize= (12, 5))

print(axes)
# Out:
# [[<Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: >]]

# %%
fig, axes = plt.subplots(nrows= 3, ncols= 3, figsize= (12, 6))

print(axes)
# Out:
# [[<Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: >]]

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 3, figsize= (10, 5))

axes[0, 0].plot([1, 2, 3], [4, 5, 6])

axes[0, 1].scatter([1, 2, 3], [4, 5, 6])

axes[0, 2].bar([1, 2, 3], [4, 5, 6])

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4])

axes[1, 1].pie([1, 2, 3], labels= ["A", "B", "C"])

axes[1, 2].imshow([[1, 2], [3, 4]])

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 3, figsize= (10, 5))

axes[0, 0].plot([1, 2, 3], [4, 5, 6], color= "b")

axes[0, 1].scatter([1, 2, 3], [4, 5, 6], color= "r")

axes[0, 2].bar([1, 2, 3], [4, 5, 6], color= "m")

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4], color= "c")

axes[1, 1].pie([1, 2, 3], labels= ["A", "B", "C"])

axes[1, 2].imshow([[1, 2], [3, 4]])
