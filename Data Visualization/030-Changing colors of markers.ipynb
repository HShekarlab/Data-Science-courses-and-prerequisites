#        -1.23322156, -0.92889094,  0.07029719, -0.4195202 , -0.69591621,
#         0.40558931, -1.36251574, -1.12505822,  0.3743144 , -0.25607432,
#        -1.32302468,  1.39078126, -1.10697732, -1.81090233,  0.55646032,
#         0.14219315, -0.64357089,  1.42646955,  0.12993728, -0.16964012,
#        -0.1327045 ,  0.67109703,  0.6195629 , -1.36883624,  0.68746915,
#         0.01171999,  1.08130516,  0.0525307 , -1.06161039, -1.40188026,
#        -0.12218089, -1.190237  , -1.76923926, -0.39392576,  0.40273554,
#        -0.43005991, -1.19566165,  0.94608076, -0.61496913,  2.10712978,
#        -0.86024422, -0.93184791,  0.91229551,  0.21884109,  0.61120961,
#        -0.67308465,  1.08476528, -0.77079707,  0.14724942, -0.33185569])

# %%
plt.figure(figsize= (6, 6))

condition = x > 0

colors = np.where(condition, "blue", "orange")

plt.scatter(x, y, c= colors)

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
colors
# Out:
# array(['orange', 'orange', 'orange', 'orange', 'orange', 'blue', 'blue',
#        'blue', 'blue', 'blue', 'orange', 'blue', 'blue', 'orange',
#        'orange', 'blue', 'orange', 'orange', 'orange', 'blue', 'orange',
#        'blue', 'orange', 'blue', 'blue', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'blue', 'blue', 'orange', 'blue', 'blue',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'blue', 'blue',
#        'blue', 'orange', 'orange', 'orange', 'orange', 'orange', 'blue',
#        'blue', 'orange', 'orange', 'orange', 'blue', 'orange', 'blue',
#        'orange', 'blue', 'orange', 'blue', 'blue', 'orange', 'orange',
#        'orange', 'blue', 'orange', 'orange', 'blue', 'orange', 'orange',
#        'orange', 'blue', 'blue', 'blue', 'orange', 'blue', 'blue', 'blue',
#        'blue', 'orange', 'orange', 'blue', 'blue', 'blue', 'blue',
#        'orange', 'orange', 'orange', 'orange', 'blue', 'orange', 'orange',
#        'orange', 'orange', 'blue', 'orange', 'blue', 'blue', 'orange',
#        'orange'], dtype='<U6')

# %%
plt.figure(figsize= (6, 6))

condition = x > 1

colors = np.where(condition, "blue", "orange")

plt.scatter(x, y, c= colors)

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
z = np.random.normal(0, 0.5, 100)

# %%
z
# Out:
# array([ 0.04736401,  0.11949063,  0.13798707,  0.22100751,  0.53735562,
#         0.45809265,  0.260395  , -0.39595949,  0.7760494 , -0.15643107,
#        -1.01385864,  0.12769373, -0.64231263,  0.15324331, -0.32202935,
#        -0.30580402, -0.96845996,  0.94894806,  0.20827883,  0.26538966,
#        -0.26617855, -0.3169724 ,  0.5487337 ,  0.43314802, -0.35484956,
#         0.39466133,  0.08622952,  0.61516311,  0.18200168,  0.82652616,
#         0.26806355, -0.13780666,  1.01626745,  0.30404476,  0.48213061,
#        -0.55393978,  1.08270215, -0.50168009,  0.73754746, -0.53278487,
#         0.08046359,  0.11770634, -0.07475141,  0.38090893,  0.02149007,
#         0.21208559,  0.56158843,  0.49964635,  0.81277163, -0.38660797,
#        -0.08202967, -0.33476681, -0.72465246, -0.02513832,  0.4103538 ,
#         0.67456893,  0.4217839 ,  0.06310407,  0.34446847,  0.86626047,
#         0.24065858,  0.0457513 ,  0.81587684, -0.98065634,  0.32164034,
#         0.13598709, -0.21974035, -0.13220383, -0.24240321, -0.35948184,
#        -0.25303765, -0.51881346,  0.61496706,  0.15030071, -0.82466796,
#        -0.39999926,  0.8516243 , -0.50145793,  0.11375276,  0.199635  ,
#         0.13727732,  0.07602431,  0.00809482,  0.32941782,  0.27259582,
#         0.30087856,  0.01351135, -0.46477995, -0.62982241, -0.12620939,
#        -0.1359618 , -0.04020266,  0.53149426,  0.35919653, -0.05517842,
#         0.05150148,  0.28531833,  1.168702  ,  0.79044161, -0.44850214])

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= "0.46846257", cmap= "cool")

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# C:\Users\H_PC\AppData\Local\Temp\ipykernel_7556\3823322655.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c= "0.46846257", cmap= "cool")
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= "0.46846257", cmap= "cool")
plt.colorbar()

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# C:\Users\H_PC\AppData\Local\Temp\ipykernel_7556\2383135381.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c= "0.46846257", cmap= "cool")
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= z, cmap= "cool")

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= z, cmap= "magma")
plt.colorbar()

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= z, cmap= "viridis")
plt.colorbar()

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')

# %%
plt.figure(figsize= (6, 6))

plt.scatter(x, y, c= z, cmap= "hot")
plt.colorbar()

plt.title("Scatter Plot with Custom Marker Colors based on Condition")
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
# Out:
# Text(0, 0.5, 'Y - axis label')
