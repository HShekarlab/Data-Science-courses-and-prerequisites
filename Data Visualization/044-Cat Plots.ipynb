# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "swarm", palette= "husl")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(41.41150694444444, 0.5, 'Tip')

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "point", palette= "Set2")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(44.01800694444444, 0.5, 'Tip')

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "bar", palette= "Paired")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(42.288694444444445, 0.5, 'Tip')

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "box", palette= "viridis")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(41.41150694444444, 0.5, 'Tip')

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "violin", palette= "flare")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(41.41150694444444, 0.5, 'Tip')

# %%
sns.catplot(data= tips, x= "day", y= "tip", hue= "sex", kind= "strip", palette= "magma")

plt.title("Tip by Day and Sex")
plt.xlabel("Day of the Week")
plt.ylabel("Tip")
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(41.41150694444444, 0.5, 'Tip')
